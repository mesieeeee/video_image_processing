# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.1/871.1 kB 34.0 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source = '/content/MOT16-03.mp4'
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 344MB/s]
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/1500) /content/MOT16-03.mp4: 384x640 23 persons, 4 bicycles, 1 car, 1 motorcycle, 1 backpack, 1 potted plant, 108.9ms
# video 1/1 (frame 2/1500) /content/MOT16-03.mp4: 384x640 24 persons, 2 bicycles, 1 car, 1 motorcycle, 1 backpack, 25.4ms
# video 1/1 (frame 3/1500) /content/MOT16-03.mp4: 384x640 20 persons, 2 bicycles, 1 car, 1 motorcycle, 25.3ms
# video 1/1 (frame 4/1500) /content/MOT16-03.mp4: 384x640 23 persons, 2 bicycles, 1 car, 1 motorcycle, 1 potted plant, 25.3ms
# video 1/1 (frame 5/1500) /content/MOT16-03.mp4: 384x640 22 persons, 2 bicycles, 1 car, 1 motorcycle, 25.3ms
# video 1/1 (frame 6/1500) /content/MOT16-03.mp4: 384x640 22 persons, 2 bicycles, 1 car, 1 motorcycle, 1 potted plant, 25.3ms
# ...

# %%
# !ffmpeg -i {'/content/runs/detect/predict/MOT16-03.avi'} -vcodec libx264 {'final.mp4'}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
